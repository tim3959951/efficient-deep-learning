# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: filelock in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import numpy as np
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
import matplotlib.ticker as ticker


# Load the MNIST dataset
mnist = fetch_openml('mnist_784', version=1, cache=True, as_frame=False)
# Convert data and target to numpy arrays
data = mnist.data
target = mnist.target.astype(np.uint8)  # convert labels from string to integer

# Split into training and testing sets
train_imgs = data[:60000]
train_labels = target[:60000]
test_imgs = data[60000:]
test_labels = target[60000:]

# Visualize some images and labels
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(train_imgs[i].reshape(28, 28), cmap='gray')
    ax.set_title("Label: {}".format(train_labels[i]))
    ax.axis('off')

plt.show()

# Convert numpy arrays to PyTorch tensors
train_imgs = torch.from_numpy(train_imgs).float()
train_labels = torch.from_numpy(train_labels)
test_imgs = torch.from_numpy(test_imgs).float()
test_labels = torch.from_numpy(test_labels)

# Create data loaders
train_dataset = TensorDataset(train_imgs, train_labels)
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)

test_dataset = TensorDataset(test_imgs, test_labels)
test_loader = DataLoader(test_dataset, batch_size=1)

class FFNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(FFNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)

    def forward(self, x):
        x = self.leaky_relu(self.fc1(x))
        x = self.fc2(x)
        return x
# Out:
# /Users/tim/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
# Instantiate the network
input_dim = 784  # MNIST images are 28x28
hidden_dim = 100
output_dim = 10  # 10 classes

learning_rates = [0.0001, 0.0002, 0.0003, 0.0005]
for lr in learning_rates:
    print(f'Training with learning rate: {lr}')
    model = FFNN(input_dim, hidden_dim, output_dim)
    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    # Training
    epochs = 100
    best_accuracy = 0
    epochs_without_improvement = 0
    accuracies = []
    cumulative_energy_consumption = 0
    energy_consumptions = []
    for epoch in range(epochs):
        energy_consumption = 0
        for images, labels in train_loader:
            # Clear gradients
            optimizer.zero_grad()
            # Forward propagation
            outputs = model(images)
            # Calculate loss
            loss = criterion(outputs, labels)
            # Backpropagation
            loss.backward()
            # Save the current weights
            weights_before_update = [w.clone() for w in model.parameters()]
            # Update weights
            optimizer.step()
            # Calculate the size of the weight updates using L1 norm
            weight_updates = [weights_before_update[i] - w for i, w in enumerate(model.parameters())]
            weight_update_sizes = [w.abs().sum().item() for w in weight_updates]  # L1 norm
            # Estimate the energy consumption as the sum of the weight update sizes
            energy_consumption += sum(weight_update_sizes)
        cumulative_energy_consumption += energy_consumption
        energy_consumptions.append(cumulative_energy_consumption)

        # Test
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in test_loader:
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
        accuracies.append(accuracy)
        print(f'Epoch {epoch+1}, Accuracy: {accuracy}%')

        # Stop training if accuracy reaches 95%
        if accuracy >= 95:
            print(f'Stopping training after reaching {accuracy}% accuracy.')
            break

    plt.semilogy(accuracies, energy_consumptions, label=f'lr={lr}')

plt.xlabel('Accuracy')
plt.ylabel('Cumulative Energy Consumption')
plt.title('Cumulative Energy Consumption vs Accuracy')
plt.legend()
plt.show()
# Out:
# Training with learning rate: 0.0001
# Epoch 1, Accuracy: 93.06%
# Epoch 2, Accuracy: 94.23%
# Epoch 3, Accuracy: 94.82%
# Epoch 4, Accuracy: 95.33%
# Stopping training after reaching 95.33% accuracy.
# Training with learning rate: 0.0002
# Epoch 1, Accuracy: 92.5%
# Epoch 2, Accuracy: 93.35%
# Epoch 3, Accuracy: 93.94%
# Epoch 4, Accuracy: 94.85%
# Epoch 5, Accuracy: 94.41%
# Epoch 6, Accuracy: 94.71%
# Epoch 7, Accuracy: 95.03%
# Stopping training after reaching 95.03% accuracy.
# Training with learning rate: 0.0003
# Epoch 1, Accuracy: 92.01%
# Epoch 2, Accuracy: 92.84%
# Epoch 3, Accuracy: 93.78%
# Epoch 4, Accuracy: 93.98%
# Epoch 5, Accuracy: 93.68%
# Epoch 6, Accuracy: 94.29%
# Epoch 7, Accuracy: 94.3%
# Epoch 8, Accuracy: 94.15%
# Epoch 9, Accuracy: 94.04%
# Epoch 10, Accuracy: 94.14%
# Epoch 11, Accuracy: 94.84%
# Epoch 12, Accuracy: 94.85%
# Epoch 13, Accuracy: 95.01%
# Stopping training after reaching 95.01% accuracy.
# Training with learning rate: 0.0005
# Epoch 1, Accuracy: 90.49%
# Epoch 2, Accuracy: 91.87%
# Epoch 3, Accuracy: 91.03%
# Epoch 4, Accuracy: 89.92%
# Epoch 5, Accuracy: 92.3%
# Epoch 6, Accuracy: 90.63%
# Epoch 7, Accuracy: 89.24%
# Epoch 8, Accuracy: 92.44%
# Epoch 9, Accuracy: 92.02%
# Epoch 10, Accuracy: 92.31%
# Epoch 11, Accuracy: 89.89%
# Epoch 12, Accuracy: 91.55%
# Epoch 13, Accuracy: 92.01%
# Epoch 14, Accuracy: 93.27%
# Epoch 15, Accuracy: 91.59%
# Epoch 16, Accuracy: 91.01%
# Epoch 17, Accuracy: 91.52%
# Epoch 18, Accuracy: 91.0%
# Epoch 19, Accuracy: 89.51%
# Epoch 20, Accuracy: 90.94%
# Epoch 21, Accuracy: 92.47%
# Epoch 22, Accuracy: 92.67%
# Epoch 23, Accuracy: 91.89%
# Epoch 24, Accuracy: 91.35%
# Epoch 25, Accuracy: 92.86%
# Epoch 26, Accuracy: 90.09%
# Epoch 27, Accuracy: 92.4%
# Epoch 28, Accuracy: 86.22%
# Epoch 29, Accuracy: 89.62%
# Epoch 30, Accuracy: 87.27%
# Epoch 31, Accuracy: 87.66%
# Epoch 32, Accuracy: 90.87%
# Epoch 33, Accuracy: 87.94%
# Epoch 34, Accuracy: 92.27%
# Epoch 35, Accuracy: 92.08%
# Epoch 36, Accuracy: 91.04%
# Epoch 37, Accuracy: 89.52%
# Epoch 38, Accuracy: 90.31%
# Epoch 39, Accuracy: 90.11%
# Epoch 40, Accuracy: 93.05%
# Epoch 41, Accuracy: 92.62%
# Epoch 42, Accuracy: 93.04%
# Epoch 43, Accuracy: 92.86%
# Epoch 44, Accuracy: 92.03%
# Epoch 45, Accuracy: 93.49%
# Epoch 46, Accuracy: 89.13%
# Epoch 47, Accuracy: 89.63%
# Epoch 48, Accuracy: 91.36%
# Epoch 49, Accuracy: 92.02%
# Epoch 50, Accuracy: 92.81%
# Epoch 51, Accuracy: 91.64%
# Epoch 52, Accuracy: 92.6%
# Epoch 53, Accuracy: 93.32%
# Epoch 54, Accuracy: 91.56%
# Epoch 55, Accuracy: 92.49%
# Epoch 56, Accuracy: 91.84%
# Epoch 57, Accuracy: 92.1%
# Epoch 58, Accuracy: 88.1%
# Epoch 59, Accuracy: 92.05%
# Epoch 60, Accuracy: 92.02%
# Epoch 61, Accuracy: 92.17%
# Epoch 62, Accuracy: 91.96%
# Epoch 63, Accuracy: 92.85%
# Epoch 64, Accuracy: 88.62%
# Epoch 65, Accuracy: 92.91%
# Epoch 66, Accuracy: 89.01%
# Epoch 67, Accuracy: 91.16%
# Epoch 68, Accuracy: 90.29%
# Epoch 69, Accuracy: 92.4%
# Epoch 70, Accuracy: 93.26%
# Epoch 71, Accuracy: 87.9%
# Epoch 72, Accuracy: 90.65%
# Epoch 73, Accuracy: 91.45%
# Epoch 74, Accuracy: 92.33%
# Epoch 75, Accuracy: 92.45%
# Epoch 76, Accuracy: 87.68%
# Epoch 77, Accuracy: 91.8%
# Epoch 78, Accuracy: 90.39%
# Epoch 79, Accuracy: 88.15%
# Epoch 80, Accuracy: 92.6%
# Epoch 81, Accuracy: 92.48%
# Epoch 82, Accuracy: 90.96%
# Epoch 83, Accuracy: 93.29%
# Epoch 84, Accuracy: 90.97%
# Epoch 85, Accuracy: 91.78%
# Epoch 86, Accuracy: 92.28%
# Epoch 87, Accuracy: 91.67%
# Epoch 88, Accuracy: 92.32%
# Epoch 89, Accuracy: 91.42%
# Epoch 90, Accuracy: 92.35%
# Epoch 91, Accuracy: 91.11%
# Epoch 92, Accuracy: 92.8%
# Epoch 93, Accuracy: 91.63%
# Epoch 94, Accuracy: 91.68%
# Epoch 95, Accuracy: 92.25%
# Epoch 96, Accuracy: 90.5%
# Epoch 97, Accuracy: 92.61%
# Epoch 98, Accuracy: 92.3%
# Epoch 99, Accuracy: 84.55%
# Epoch 100, Accuracy: 92.59%
